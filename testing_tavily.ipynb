# %%
from langchain_community.tools.tavily_search import TavilySearchResults
#from langchain_tavily import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026 in 200 words'})
results
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14488\501417127.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'Timeline Of ChatGPT Updates & Key Events',
#   'url': 'https://www.searchenginejournal.com/history-of-chatgpt-timeline/488370',
#   'content': 'Aug. 28, 2023 – OpenAI launched ChatGPT Enterprise, calling it “the most powerful version of ChatGPT yet.” Benefits included enterprise-level security and unlimited usage of GPT-4. (OpenAI)\n\nNov. 6, 2023 – OpenAI announced the arrival of custom GPTs, which enabled users to build their own custom GPT versions using specific skills, knowledge, etc. (OpenAI)\n\nJan. 10, 2024 – With the launch of the GPT Store, ChatGPT users could discover and use other people’s custom GPTs. On this day, OpenAI also introduced ChatGPT Team, a collaborative tool for the workspace. (OpenAI)\n\nJan. 25, 2024 – OpenAI released new embedding models: the text-embedding-3-small model, and a larger and more powerful text-embedding-3-large model. (OpenAI) [...] March 21, 2023 – Google launched Bard, its ChatGPT alternative. (Rebranded to Gemini in February 2024.)\n\nMarch 23, 2023 – OpenAI began rolling out ChatGPT plugin support, including Browsing and Code Interpreter.\n\nMarch 31, 2023 – Italy banned ChatGPT for collecting personal data and lacking age verification during registration for a system that can produce harmful content.\n\nApril 25, 2023 – OpenAI added new ChatGPT data controls that allow users to choose which conversations OpenAI includes in training data for future GPT models.\n\nApril 28, 2023 – The Italian Garante released a statement that OpenAI met its demands and that the ChatGPT service could resume in Italy.\n\nApril 29, 2023 – OpenAI released ChatGPT plugins, GPT-3.5 with browsing, and GPT-4 with browsing in ALPHA. [...] Feb. 8, 2024 – Google’s Bard rebranded to Gemini. (Google – Gemini release notes)\n\nApril 9, 2024 – OpenAI announced that it would discontinue ChatGPT plugins in favor of custom GPTs. (Open AI Community Forum)\n\nMay 13, 2024 – A big day for OpenAI, when the company introduced the GPT-4o model, offering enhanced intelligence and additional features for free users. (OpenAI)\n\nJuly 25, 2024 – OpenAI launched SearchGPT, an AI-powered search prototype designed to answer user queries with direct answers. Update: Elements from this prototype were rolled into ChatGPT and made available to all regions on Feb. 5, 2025. (OpenAI)\n\nAug. 29, 2024 – ChatGPT reaches 200 million weekly active users. (Reuters)\n\nSept. 12, 2024 – OpenAI unveiled the GPT o1 model, which it claims “can reason like a human.”',
#   'score': 0.9177831},
#  {'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#   'url': 'https://objects.ws/blog/chatgpt-version-history',
#   'content': '| ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026. | This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. |\n| ChatGPT 5.2 | December 2025 | The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone. |\n| ChatGPT 5.1 | November 2025 | Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses. |\n| ChatGPT 5 | August 2025 | GPT-5 demonstrated tool coordination, context management, and improved reasoning. | [...] | Introducing OpenAI Operator Agent | January 2025 | The agent benefited from GPT-4’s vision and reasoning capabilities to enhance interactions with web pages. |\n| Scheduled Tasks in ChatGPT | January 2025 | This update helped automate schedule tasks. Users could configure notifications, daily reports, and AI-generated messages. |\n| OpenAI o3 Preview | December 2024 | This model offered enhancements in problem-solving, reliability, and self-correction. |\n| Full o1 Model Launch | December 2024 | This model was more productive than the previous o1-preview model. Users availed themselves of features such as function calling, image analysis, and the “Reasoning Effort” parameter. | [...] | GPT-4o Mini | July 2024 | This release was more powerful than GPT-3. Moreover, there were general claims of comparable performance for GPT-3.5. Similarly, small model performance was mostly in the best-in-test category for some academic benchmarks. |\n| GPT-4o Launch | May 2024 | A groundbreaking model that offered GPT-4-level intelligence with greater speed and multimodal capabilities (including text, voice, and vision). |\n| DALL·E 3 Integration with ChatGPT | October 2023 | A much-improved image generation experience was fully integrated into ChatGPT, enabling users to generate vivid images from conversational requests. |\n| ChatGPT Android App Launch | July 2023 | ChatGPT was launched on the Google Play Store. Android users downloaded ChatGPT’s Android app from the Google Play Store. |',
#   'score': 0.9067276}]
